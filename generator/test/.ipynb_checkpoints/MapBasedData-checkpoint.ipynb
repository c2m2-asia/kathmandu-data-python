# %%
import pandas as pd
import numpy as np
import folium
from folium.plugins import HeatMap

# %%
business_df = pd.read_excel('../raw/business_data.xlsx')
variable_map = pd.read_excel('../data/map_viz_variable.xlsx')

# %%
business_df.head()
# Out:
#                          m_start                          m_end     m_today  \
# 0  2021-04-28T15:14:45.949+05:45  2021-04-28T15:33:20.591+05:45  2021-04-28
# 1  2021-05-07T10:59:17.820+05:45  2021-05-07T11:21:20.855+05:45  2021-05-07
# 2  2021-04-26T17:28:00.072+05:45  2021-04-26T17:41:14.457+05:45  2021-04-26
# 3  2021-05-01T08:07:51.848+05:45  2021-05-01T08:45:08.379+05:45  2021-05-01
# 4  2021-05-16T19:46:28.056+05:45  2021-05-16T20:06:45.761+05:45  2021-05-16
#
#            m_username                                     m_deviceid  \
# 0  username not found  ee.humanitarianresponse.info:efUjl6IoNb0tnOVO
# 1  username not found  ee.humanitarianresponse.info:ivuI8g0MlCGor6Ft
# 2  username not found  ee.humanitarianresponse.info:0cXJ5kEGM9avnhKH
# 3  username not found  ee.humanitarianresponse.info:RyUETda2QuZoNbud
# 4  username not found  ee.humanitarianresponse.info:CS5rQbmD3nN55q2y
#
#            m_subscriberid                                         m_imei  \
# 0  subscriberid not found  ee.humanitarianresponse.info:efUjl6IoNb0tnOVO
# 1  subscriberid not found  ee.humanitarianresponse.info:ivuI8g0MlCGor6Ft
# 2  subscriberid not found  ee.humanitarianresponse.info:0cXJ5kEGM9avnhKH
# 3  subscriberid not found  ee.humanitarianresponse.info:RyUETda2QuZoNbud
# 4  subscriberid not found  ee.humanitarianresponse.info:CS5rQbmD3nN55q2y
#
#            m_phonenumber  _span_style_color_FF_finances_and_HR_span  \
# 0  phonenumber not found                                        NaN
# 1  phonenumber not found                                        NaN
# 2  phonenumber not found                                        NaN
# 3  phonenumber not found                                        NaN
# 4  phonenumber not found                                        NaN
#
#    i_econ_stop_business  ...             __version__        _id  \
# 0                     2  ...  vwGwixFVQLjhFdchggLZtd  174444706
# 1                     2  ...  vwGwixFVQLjhFdchggLZtd  176510702
# 2                     2  ...  vwGwixFVQLjhFdchggLZtd  173876161
# 3                     2  ...  vwGwixFVQLjhFdchggLZtd  175156051
# 4                     2  ...  vwGwixFVQLjhFdchggLZtd  178003908
#
#                                   _uuid     _submission_time  \
# 0  510712d3-b5f6-47e7-b3d2-9ae5f49e3b94  2021-04-28T09:47:31
# 1  8ff407ec-6aab-46c8-bb5b-cc48219cc389  2021-05-07T05:36:20
# 2  fd294dd2-9126-4feb-9b54-a0d41843f063  2021-04-26T11:57:05
# 3  76b937cb-67fb-4892-ac32-5ec77e023929  2021-05-01T03:00:10
# 4  d9cfe125-2298-41e8-bdd8-17e7262ebbdb  2021-05-16T14:21:47
#
#    _validation_status  _notes            _status  _submitted_by  _tags  _index
# 0                 NaN      []  submitted_via_web            NaN    NaN      36
# 1                 NaN      []  submitted_via_web            NaN    NaN     109
# 2                 NaN      []  submitted_via_web            NaN    NaN       8
# 3                 NaN      []  submitted_via_web            NaN    NaN      69
# 4                 NaN      []  submitted_via_web            NaN    NaN     110
#
# [5 rows x 310 columns]

# %%
business_map_df = business_df[['m_name_business', 'm_today', 'm_coodinates']]
business_map_df = business_map_df[business_map_df['m_coodinates']!=' ']

# %%
business_map_df['coordinates'] = business_map_df['m_coodinates'].apply(func= lambda x: (float(x.split(' ')[0]), float(x.split(' ')[1])))
business_map_df.drop('m_coodinates', axis=1, inplace=True)

# %%
business_map_df.head()
# Out:
#                m_name_business     m_today  \
# 0  Shisha Lounge & Bar Pvt Ltd  2021-04-28
# 1        Hotel Vinayak pvt ltd  2021-05-07
# 2        chitwan forest resort  2021-04-26
# 3                  Suburb cafe  2021-05-01
# 4              hostel nextdoor  2021-05-16
#
#                             coordinates
# 0  (27.7153038584918, 85.3103238891712)
# 1                  (26.98806, 85.89996)
# 2                  (27.58148, 84.49332)
# 3                (27.684759, 85.312688)
# 4                (27.684944, 85.315922)

# %%
selected_variables = variable_map[variable_map['selected']=='yes']
s_select_variables = selected_variables[selected_variables['input_type']=='single-select']['variable'].tolist()
multi_select_variables = selected_variables[selected_variables['input_type']=='multi-select']['variable'].tolist()

# %%
s_select_variables
# Out:
#                                  variable  \
# 0                    i_econ_stop_business
# 1            i_econ_stop_business_how_lng
# 22         i_wrkfrc_size_chng_2020_v_2019
# 23         i_fin_revenue_chng_2020_v_2019
# 24         i_fin_savings_chng_2020_v_2019
# 41    n_rcvry_preferred_loan_pybck_incntv
# 42    n_rcvry_preferred_fund_aprvl_incntv
# 43           n_rcvry_preferred_fin_source
# 45           n_rcvry_preferred_tax_asstnc
# 46      n_rcvry_preferred_tax_asstn_other
# 47         n_rcvry_preferred_labor_asstnc
# 48       n_rcvry_preferred_outreach_other
# 49             o_do_u_know_of_gov_schemes
# 53               o_covid_how_long_it_last
# 54     o_econ_impact_revenue_chng_21_v_19
# 55      o_econ_impact_wrkfrc_chng_21_v_19
# 61                o_rcvry_biggest_support
# 64  o_perm_stop_biz_future_retrn_trsm_biz
#
#                                               ques_en  \
# 0   Did you have to stop your business due to COVI...
# 1    For how long did you have to stop your business?
# 22  Compared to 2019, how has the size of your wor...
# 23  Compared to 2019, how have your business reven...
# 24  Compared to 2019, how has your business’s savi...
# 41  Which of the following loan payback-related as...
# 42  Which of the following funds-related assistanc...
# 43  What is your preferred source (first choice) o...
# 45  Which of the following tax-related assistance ...
# 46  Which of the following operating costs-related...
# 47  Which of the following labor-related assistanc...
# 48  Which of the following business outreach-relat...
# 49  The government has announced different schemes...
# 53  How much longer do you expect the disruption d...
# 54  Compared to 2019, how much revenues does your ...
# 55  Compared to 2019, what percentage of workforce...
# 61  Who do you think will be the biggest support f...
# 64  Do you intend to return to the tourism busines...
#
#                                               ques_ne    group  \
# 0   के तपाईंले कोभिड-१९ महामारीको कारण आफ्नो व्यवस...   impact
# 1   कति समय सम्म तपाईंले आफ्नो व्यापार बन्द गर्नु ...   impact
# 22  २०१९को तुलानामा महमारिको कारणले २०२० मा तपाईंक...   impact
# 23  २०१९को तुलानामा महमारिको कारणले २०२० मा तपाईंक...   impact
# 24  २०१९को तुलानामा महमारिको कारणले २०२० मा तपाईंक...   impact
# 41  निम्न मध्ये कुन ऋण रकम फिर्ता सम्बन्धीत सहयोग ...     need
# 42  तलका कोषहरू सम्बन्धित कुन मद्दत तपाईंलाई सबैभन...     need
# 43  तपाईंको व्यावसायको लागि निम्न आर्थिक स्रोत मध्...     need
# 45  तलका करहरू सम्बन्धित कुन मद्दत तपाईंलाई सबैभन्...     need
# 46  निम्न मध्ये कुन अपरेटिंग लागत सम्बन्धित सहयोग ...     need
# 47  निम्न मध्ये कुन श्रम सम्बन्धी सहयोग तपाईंलाई स...     need
# 48  निम्न मध्ये कुन व्यापार आउटरीच सम्बन्धित सहयोग...     need
# 49  पर्यटन व्यवसायको पुनरुद्धारका लागि सरकारले विभ...     need
# 53  महामारीको कारणले भएको विघटन कति लामो हुने आशा ...  outlook
# 54  २०१९को तुलानामा २०२१मा तपाईंको व्यवसायले कति र...  outlook
# 55  २०१९को तुलानामा २०२१मा तपाईंको व्यवसायले कति प...  outlook
# 61  तपाईको व्यवसायको लागी सब भन्दा ठूलो सहयोगी को ...  outlook
# 64  के तपाइँ भविष्यमा पर्यटन व्यवसायमा फर्कनु हुनेछ ?  outlook
#
#                                       asked_condition  \
# 0                                             general
# 1                        business temporarily stopped
# 22                                            general
# 23                                            general
# 24                                            general
# 41  business will have difficulties in paying back...
# 42  business will have difficulties to acquire add...
# 43  business will have difficulties to acquire add...
# 45  business will have difficulties in paying its ...
# 46  business will have difficulties in covering it...
# 47  business will most likely face labor-related i...
# 48  business will have difficulties in getting eno...
# 49                                            general
# 53                                            general
# 54                                            general
# 55                                            general
# 61                                            general
# 64                                                NaN
#
#                                            highlights selected  \
# 0   ....% of businesses had to shut down permanently.      yes
# 1   ......% of businesses' operations was disrupte...      yes
# 22                                                NaN      yes
# 23                                                NaN      yes
# 24                                                NaN      yes
# 41                                                NaN      yes
# 42                                                NaN      yes
# 43                                                NaN      yes
# 45                                                NaN      yes
# 46                                                NaN      yes
# 47                                                NaN      yes
# 48                                                NaN      yes
# 49                                                NaN      yes
# 53                                                NaN      yes
# 54                                                NaN      yes
# 55                                                NaN      yes
# 61                                                NaN      yes
# 64                                                NaN      yes
#
#                                           Suggestions     input_type
# 0                                                 NaN  single-select
# 1                                                 NaN  single-select
# 22      businesses which reduced staff by 50% or more  single-select
# 23              curious to see how this will be shown  single-select
# 24    businesses whose savings reduced by 50% or more  single-select
# 41                                                NaN  single-select
# 42                                                NaN  single-select
# 43                                                NaN  single-select
# 45                                                NaN  single-select
# 46                                                NaN  single-select
# 47                                                NaN  single-select
# 48                                                NaN  single-select
# 49                                                NaN  single-select
# 53                                                NaN  single-select
# 54                                                NaN  single-select
# 55  businesses that hope to retain near 2019 emplo...  single-select
# 61                                                NaN  single-select
# 64       businesses that have decided to quit tourism  single-select

# %%
for i in s_select_variables:
    print(i)
#     each_var_df = business_df[['m_name_business', 'm_today', 'm_coodinates']]
#     each_var_df = each_var_df[each_var_df['m_coodinates']!=' ']
#     each_var_df['coordinates'] = each_var_df['m_coodinates'].apply(func= lambda x: (float(x.split(' ')[0]), float(x.split(' ')[1])))
#     each_var_df.drop('m_coodinates', axis=1, inplace=True)
#     each_var_df['variable'] = i
#     each_var_df['value'] = business_df[i]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'variable'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-29c845a533f6> in <module>
#       5     each_var_df.drop('m_coodinates', axis=1, inplace=True)
#       6     each_var_df['variable'] = i
# ----> 7     each_var_df['value'] = business_df[i]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'variable'

# %%
each_var_df
# Out:
#                        m_name_business     m_today  \
# 0          Shisha Lounge & Bar Pvt Ltd  2021-04-28
# 1                Hotel Vinayak pvt ltd  2021-05-07
# 2                chitwan forest resort  2021-04-26
# 3                          Suburb cafe  2021-05-01
# 4                      hostel nextdoor  2021-05-16
# ..                                 ...         ...
# 107       Thamel Seasons Hotel Pvt.ltd  2021-05-02
# 108                     Hotel Business  2021-05-03
# 109  The freedom cafe restaurant & bar  2021-05-05
# 110   Tour and trekking and Expedition  2021-05-06
# 111     Outlandish Nepal Holidays Ltd.  2021-05-26
#
#                               coordinates              variable  value
# 0    (27.7153038584918, 85.3103238891712)  i_econ_stop_business      2
# 1                    (26.98806, 85.89996)  i_econ_stop_business      2
# 2                    (27.58148, 84.49332)  i_econ_stop_business      2
# 3                  (27.684759, 85.312688)  i_econ_stop_business      2
# 4                  (27.684944, 85.315922)  i_econ_stop_business      2
# ..                                    ...                   ...    ...
# 107  (27.7179141297178, 85.3101209550944)  i_econ_stop_business      3
# 108  (27.6632585317559, 85.4449016109137)  i_econ_stop_business      2
# 109              (28.2209793, 83.9559105)  i_econ_stop_business      3
# 110  (27.7153213473598, 85.3117415550944)  i_econ_stop_business      2
# 111  (27.6742617216237, 85.3691647550934)  i_econ_stop_business      2
#
# [109 rows x 5 columns]

# %%
base_map = folium.Map(location=[27.7, 85.3240], zoom_start=13)
HeatMap(data=business_map_df['coordinates'], radius=9, max_zoom=13, ).add_to(base_map)
# base_map.save('kirana_heatmap.html')
base_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_4184ad7393cd4060857ff7fc1a63a006%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//leaflet.github.io/Leaflet.heat/dist/leaflet-heat.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4184ad7393cd4060857ff7fc1a63a006%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4184ad7393cd4060857ff7fc1a63a006%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_4184ad7393cd4060857ff7fc1a63a006%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B27.7%2C85.324%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%2013%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...
